# %% [markdown]
# Now that we have everything working, we need to check. Here we build a tool to make a video and annotate it.

# %%
import cv2 as cv 
import numpy as np

from flytracker.components import Frame
from flytracker.utils import run_tracker, FourArenasQRCodeMask
import matplotlib.pyplot as plt 

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%time
dataset = run_tracker(1000, n_flies=40)
# Out:
# CPU times: user 2min 40s, sys: 6.46 s, total: 2min 47s
# Wall time: 26.2 s

# %% [markdown]
# # Loading images

# %%
# For now we have to cycle through the first frames
path = '/Users/gert-janboth/Documents/flyTracker/data/movies/4arenas_QR.h264'
mask = FourArenasQRCodeMask().mask

capture = cv.VideoCapture(path)

images = []
for frame_idx in np.arange(1000):
    images.append(Frame(capture.read()[1], mask))

# %%
plt.figure(figsize=(15, 15))
plt.imshow(images[0](), cmap='gray')

# %%
cv.imshow()
