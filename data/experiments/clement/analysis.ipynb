# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_hdf('tracks.hdf')

# %%
for _, fly in df.query("arena==3").groupby("ID"):
    plt.plot(fly.x, fly.y)

# %%
df.query("ID==0").frame.max()
# Out:
# 108051.0

# %%
for _, fly in df.query("arena==1").groupby("ID"):
    plt.plot(fly.x, fly.y)

# %%
for _, fly in df.query("arena==2").groupby("ID"):
    plt.plot(fly.x, fly.y)

# %%
for _, fly in df.query("arena==3").groupby("ID"):
    plt.plot(fly.x, fly.y)

# %%
import torch
import numpy as np
from flytracker import run
from flytracker.analysis import annotate

movie_path = "/Users/gjboth/Documents/flyTracker/data/experiments/clement/seq_1.mp4"
mapping_folder = "data/distortion_maps/"

# Making mask
mask = torch.ones((1080, 1280), dtype=bool)
mask[:160, :] = 0
mask[-120:, :] = 0
mask[:, :220] = 0
mask[:, -240:] = 0


print("Running tracker.")
df = run(movie_path, mask, n_arenas=4, gpu=False, max_change=np.inf, n_frames=5000)
# Out:
# /Users/gjboth/miniconda3/lib/python3.9/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# Running tracker.
# Done with frame 1000
# Done with frame 2000
# Done with frame 3000
# Done with frame 4000
# Done with frame 5000

# %%
df.shape
# Out:
# torch.Size([5002, 40, 3])

# %%
from flytracker.analysis import post_process

# %%
post_process(df, 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/45/h8f5rzyj4018s4vfq06wrh9h0000gn/T/ipykernel_37151/796864624.py in <module>
# ----> 1 post_process(df, 4)
#
# ~/Documents/flyTracker/src/flytracker/analysis/postprocessing.py in post_process(locations, n_arenas)
#      14     # Making dataframe
#      15     df = pd.DataFrame(
# ---> 16         np.concatenate([identities, np.concatenate(locations, axis=0)], axis=1),
#      17         columns=["ID", "x", "y", "frame"],
#      18     )
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: The first input argument needs to be a sequence
