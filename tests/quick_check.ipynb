# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_hdf('df.hdf', key='df')

# %%
df
# Out:
#         frame  ID           x           y  arena
# 0         100   0  454.543243  870.999695      0
# 1         100   1  341.084900  973.584045      0
# 2         100   2  335.558624  958.352173      0
# 3         100   3  277.423035  859.742554      0
# 4         100   4  221.745148  820.429382      0
# ...       ...  ..         ...         ...    ...
# 400075  10101  35  602.238220  416.023773      3
# 400076  10101  36  659.984009  492.619019      3
# 400077  10101  37  585.631531  456.421051      3
# 400078  10101  38  702.580627  559.871094      3
# 400079  10101  39  684.254272  509.576263      3
#
# [400080 rows x 5 columns]

# %%
ID = 2
plt.plot(*df.query(f"ID == {ID}")[["x", "y"]].to_numpy().T, '-')

# %%
for ID in df.ID.unique():
    plt.plot(*df.query(f"ID == {ID}")[["x", "y"]].to_numpy().T, '-')

# %%
arena = 0
for ID in df.query(f'arena == {arena}').ID.unique():
    plt.plot(*df.query(f"ID == {ID}")[["x", "y"]].to_numpy().T, '-')

# %%
# Out:
#        frame  ID           x           y  arena
# 0        100   0  322.441437  373.146881      0
# 1        100   1  213.723129  500.770416      0
# 2        100   2  231.732574  450.659485      0
# 3        100   3  226.403046  509.605865      0
# 4        100   4  278.758209  377.671783      0
# ...      ...  ..         ...         ...    ...
# 40075   1101  35  691.333374  432.924316      3
# 40076   1101  36  697.437500  462.062500      3
# 40077   1101  37  790.142761  442.809540      3
# 40078   1101  38  587.954529  544.318176      3
# 40079   1101  39  601.999939  556.605286      3
#
# [40080 rows x 5 columns]
