# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_hdf('df.hdf', key='df')

# %%
ID = 0
plt.plot(*df.query(f"ID == {ID}")[["x", "y"]].to_numpy().T)

# %%
for ID in np.arange(df.ID.unique().size):
    plt.plot(*df.query(f"ID == {ID}")[["x", "y"]].to_numpy().T)
